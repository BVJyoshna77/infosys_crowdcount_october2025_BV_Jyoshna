# %%
#task1

class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, a, b):
        self.result = a + b
        return self.result

    def subtract(self, a, b):
        self.result = a - b
        return self.result

    def multiply(self, a, b):
        self.result = a * b
        return self.result

    def divide(self, a, b):
        if b != 0:
            self.result = a / b
            return self.result
        else:
            return "Error: Division by zero"

calc = Calculator()
print("Add:", calc.add(10, 5))
print("Subtract:", calc.subtract(10, 5))
print("Multiply:", calc.multiply(10, 5))
print("Divide:", calc.divide(10, 0))
# Out:
# Add: 15
# Subtract: 5
# Multiply: 50
# Divide: Error: Division by zero

# %%
#task2 

#multiple inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):   # Inheriting from both A and B
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()
# Out:
# Feature 1 from A
# Feature 2 from B
# Feature 3 from C

# %%
#multilevel inheritance
class Grandparent:
    def show_grandparent(self):
        print("I am Grandparent")

class Parent(Grandparent):
    def show_parent(self):
        print("I am Parent")

class Child(Parent):
    def show_child(self):
        print("I am Child")

c = Child()
c.show_grandparent()
c.show_parent()
c.show_child()
# Out:
# I am Grandparent
# I am Parent
# I am Child

# %%
#hierarchical inheritancclass Parent:
def show_parent(self):
        print("I am Parent")

class Child1(Parent):
    def show_child1(self):
        print("I am Child 1")

class Child2(Parent):
    def show_child2(self):
        print("I am Child 2")

c1 = Child1()
c1.show_parent()
c1.show_child1()

c2 = Child2()
c2.show_parent()
c2.show_child2()
# Out:
# I am Parent
# I am Child 1
# I am Parent
# I am Child 2

# %%
#task3

# Method Overriding Example
class Parent:
    def show(self):
        print("This is Parent class")

class Child(Parent):
    # Overriding Parent method
    def show(self):
        print("This is Child class (overrides Parent)")

c = Child()
c.show()   # Child version runs, not Parent
# Out:
# This is Child class (overrides Parent)

# %%
# Method Overloading 
class Calculator:
    def add(self, a=None, b=None, c=None):
        if a is not None and b is not None and c is not None:
            return a + b + c
        elif a is not None and b is not None:
            return a + b
        elif a is not None:
            return a
        else:
            return 0

calc = Calculator()
print("add(2):", calc.add(2))
print("add(2, 3):", calc.add(2, 3))
print("add(2, 3, 4):", calc.add(2, 3, 4))
# Out:
# add(2): 2
# add(2, 3): 5
# add(2, 3, 4): 9
